# %%
# Sample data
data = [
    (1, "John", "Kolkata", 25),
    (2, "Alice", "Delhi", 32),
    (3, "Bob", "Mumbai", 45),
    (4, "David", "Delhi", 28),
    (5, "Eva", "Kolkata", 39)
]

# Define schema
columns = ["customer_id", "name", "city", "age"]

# Create DataFrame
df = spark.createDataFrame(data, columns)

# Display in Databricks notebook
display(df)

# %%
# New rows to add
new_data = [
    (6, "Frank", "Chennai", 41),
    (7, "Grace", "Pune", 29)
]

new_columns = ["customer_id", "name", "city", "age"]

# Create new DataFrame
df_new = spark.createDataFrame(new_data, new_columns)

# Append to existing table
df_new.write.mode("append").saveAsTable("projects.default.customer_data")

# %%
# Sample order data
orders_data = [
    (101, 1, "Laptop", 75000),
    (102, 2, "Phone", 30000),
    (103, 3, "Tablet", 20000),
    (104, 5, "Headphones", 5000)
]

orders_columns = ["order_id", "customer_id", "product", "amount"]

# Create DataFrame
orders_df = spark.createDataFrame(orders_data, orders_columns)

# Save as a new table
orders_df.write.mode("overwrite").saveAsTable("projects.default.orders")

# %%
# %sql
-- Check customer table
SELECT * FROM projects.default.customer_data;

# %%
# %sql
SELECT * FROM projects.default.orders;

# %%
# %sql
USE CATALOG projects;
USE SCHEMA default;

# %%
orders_data = [
    (101, 1, "Laptop", 75000),
    (102, 2, "Phone", 30000),
    (103, 3, "Tablet", 20000),
    (104, 5, "Headphones", 5000)
]

orders_columns = ["order_id", "customer_id", "product", "amount"]

orders_df = spark.createDataFrame(orders_data, orders_columns)

# Save as new table under projects.default
orders_df.write.mode("append").saveAsTable("orders")

# %%
orders_data = [
    (101, 1, "Laptop", 75000),
    (102, 2, "Phone", 30000),
    (103, 3, "Tablet", 20000),
    (104, 5, "Headphones", 5000)
]

orders_columns = ["order_id", "customer_id", "product", "amount"]

orders_df = spark.createDataFrame(orders_data, orders_columns)

# Save as new table under projects.default
orders_df.write.mode("append").saveAsTable("orders")

# %%
# %sql
DESCRIBE TABLE customer_data;

# %%
# %sql
DESCRIBE TABLE orders;

# %%
# %sql
DESCRIBE DETAIL customer_data;

# %%
# %sql
DESCRIBE HISTORY orders;

# %%
# %sql
DESCRIBE HISTORY customer_data;

# %%
# %sql
DESCRIBE DETAIL orders;

# %%
from delta.tables import DeltaTable

# Reference the table by name (no need for DBFS path)
dt = DeltaTable.forName(spark, "orders")

# Show transaction history
display(dt.history())

# %%
# Read version 0 of the table
spark.read.format("delta").option("versionAsOf", 0).table("orders").show()

# %%
spark.read.format("delta") \
    .option("timestampAsOf", "2026-08-30T06:33:53.000+00:00") \
    .table("orders") \
    .show()

# %%
# Save DataFrame as a managed table in Databricks
df.write.mode("overwrite").saveAsTable("projects.default.customer_data")

# %%
# %sql
SELECT * FROM customer_data VERSION AS OF 3;

# %%
# %sql
SELECT * FROM customer_data TIMESTAMP AS OF '2026-08-30T06:33:53.000+00:00';

# %%
# %sql
OPTIMIZE customer_data

# %%
# %sql
OPTIMIZE customer_data
ZORDER BY (city);

# %%
from delta.tables import DeltaTable

dt = DeltaTable.forName(spark, "customer_data")
display(dt.history())

# %%
# %sql
DESCRIBE DETAIL customer_data;

# %%
# %sql
describe history customer_data
